# %%
import numpy as np
from datetime import date
import os
import json
import ffmpeg
from math import ceil
import traceback

# %%
"""
- image (a list that we already know the length by the length of the video, so we can make it ordered)
- annotation (a list that will be randomized order, but annotation id would be the same)

Parameters:
    filepath
    fileid - for making the image and annotation id

get the overall video length
get the general width and height of the video

image
    - go through and create the image files 

annotation
    - it's a dictionary, we just iterate through them
    - get the time stamp so that we can create the annotation id (how to deal with the object annoation part)
    - have a dictionary (we could initalize it): for each time stamp (key), we keep track of the curr object annotation id that we should use
    - steal; "area": float, "bbox": [x,y,width,height],
    - iscrowd = 0

ffmpeg use the json annotation filename to save file
"""
# Out:
# '\n- image (a list that we already know the length by the length of the video, so we can make it ordered)\n- annotation (a list that will be randomized order, but annotation id would be the same)\n\nParameters:\n    filepath\n    fileid - for making the image and annotation id\n\nget the overall video length\nget the general width and height of the video\n\nimage\n    - go through and create the image files \n\nannotation\n    - it\'s a dictionary, we just iterate through them\n    - get the time stamp so that we can create the annotation id (how to deal with the object annoation part)\n    - have a dictionary (we could initalize it): for each time stamp (key), we keep track of the curr object annotation id that we should use\n    - steal; "area": float, "bbox": [x,y,width,height],\n    - iscrowd = 0\n'

# %%
class CocoIdGenerator:
    def __init__(self, file_id, digits_for_file=3, digits_for_image=5, digits_for_obj=3):
        self.file_id = file_id
        self.digits_for_file = digits_for_file
        self.digits_for_image = digits_for_image
        self.digits_for_obj = digits_for_obj

    def generateImageId(self, curr_time_int):
        file_sec = str(self.file_id)
        file_sec = file_sec.zfill(self.digits_for_file)
        
        image_sec = str(curr_time_int)
        image_sec = image_sec.zfill(self.digits_for_image)

        return int(file_sec + image_sec)

    def generateAnnId(self, curr_time_int, obj_id):
        file_sec = str(self.file_id)
        file_sec = file_sec.zfill(self.digits_for_file)
        
        image_sec = str(curr_time_int)
        image_sec = image_sec.zfill(self.digits_for_image)
        
        obj_sec = str(obj_id)
        obj_sec = obj_sec.zfill(self.digits_for_obj)

        return int(file_sec + image_sec + obj_sec)

# %%
def getLabelAndId(attrDict, attrConfigDict):
    label = None
    object_id = None

    object_present_exist = False
    object_present_attr_key = ""
    object_id_exist = False
    object_id_attr_key = ""
    object_label_exist = False
    object_label_attr_key = ""

    mapToStandardLabel = {}

    for k in attrDict:
      if attrConfigDict[k]["aname"] == "object_present":
          object_present_exist = True
          object_present_attr_key = k
      elif attrConfigDict[k]["aname"] == "object_id":
          object_id_exist = True
          object_id_attr_key = k
      elif attrConfigDict[k]["aname"] == "object_label":
          object_label_exist = True
          object_label_attr_key = k
          
          cat_options = attrConfigDict[k]["options"]
          for og_cat_id in cat_options:
            if "shark" in cat_options[og_cat_id] or "0" == cat_options[og_cat_id]:
              mapToStandardLabel[int(og_cat_id)] = 1
            elif "human" in cat_options[og_cat_id] or "1" == cat_options[og_cat_id]:
              mapToStandardLabel[int(og_cat_id)] = 2
            else:
              print(f"not recognizable options in cat_options: {cat_options}")
              print("error at getLabelAndId")
      else:
          print(f"attrDict key: {k}")
          print("error at getLabelAndId")

    # default map
    #   shark = 0 -> 1
    #   human = 1 -> 2
    if len(mapToStandardLabel):
      mapToStandardLabel = {0:1, 1:2}

    if object_label_exist:
        original_label = int(attrDict[object_label_attr_key])
        label = mapToStandardLabel[original_label]
    elif object_present_exist:
        if "shark" in attrDict[object_present_attr_key] or "0" == attrDict[object_present_attr_key]:
            label = 1  # coco's 0 category id is 
        elif "human" in attrDict[object_present_attr_key] or "1" == attrDict[object_present_attr_key]:
            label = 2
        else:
            print(f"cannot identify object id based on: { attrDict[object_present_attr_key]}")
    else:
        print("cannot use any attribute to find label")
        print("error at getLabelAndId")

    if object_id_exist:
      object_id = int(attrDict[object_id_attr_key])

    return label, object_id

def getSegmentation(xy_region):
  _, x, y, w, h = xy_region
  return [[x, y, x+w, y, x+w, y+h, x, y+h]]

def getBBox(xy_region):
  _, x, y, w, h = xy_region
  return [x, y, w, h]

def getArea(xy_region):
  _, _, _, w, h = xy_region
  return w * h

def getCurrObjId(curr_time, cat_id, og_obj_id, curr_obj_id_dict):
  curr_time_int = int(curr_time * 10)

  if og_obj_id != None and (og_obj_id in curr_obj_id_dict[curr_time_int]["existing_obj_ids"][cat_id]):
    print(f"Ann (cat_id={cat_id}, og_obj_id={og_obj_id}, t={curr_time}) already got added, so got ignored")
    return None, curr_obj_id_dict
  else:
    curr_obj_id_dict[curr_time_int]["existing_obj_ids"][cat_id] += [og_obj_id]
    curr_obj_id = curr_obj_id_dict[curr_time_int]["curr_obj_id"]
    curr_obj_id_dict[curr_time_int]["curr_obj_id"] += 1
    return curr_obj_id, curr_obj_id_dict

ANN_AREA_FILTER_THRESHOLD = 5

# https://stackoverflow.com/questions/42021972/truncating-decimal-digits-numpy-array-of-floats
def trunc(values, decs=1):
    return np.trunc(values*10**decs)/(10**decs)

"""
- get the time stamp so that we can create the annotation id (how to deal with the object annoation part)
- have a dictionary (we could initalize it): for each time stamp (key), we keep track of the curr object annotation id that we should use
- steal; "area": float, "bbox": [x,y,width,height],
- iscrowd = 0
- errorhandling
"""
def createCocoAnnotationDict(viaObjAnnotation, viaCatConfig, higest_z, idGenerator):
  curr_obj_id_dict = {}
  for z in range(0, ceil(higest_z * 10)):
    curr_obj_id_dict[z] = {"curr_obj_id": 0, "existing_obj_ids": {1: [], 2:[]}}

  cocoAnnotations = []

  for k in viaObjAnnotation:
      ann = viaObjAnnotation[k]
      # if len of z is more than 1, not a bounding box annotation
      if len(ann["z"]) == 1:
          curr_time = ann["z"][0]
          curr_time_int = int(ann["z"][0] * 10)

          cat_id, og_obj_id = getLabelAndId(ann["av"], viaCatConfig)
          
          if ann["xy"][0] != 2:
            print(f"Ann (cat_id={cat_id}, og_obj_id={og_obj_id}, t={curr_time}) doesn't have right format for xy labels, only expect 4 points for bounding box")
          else:
            area = getArea(ann["xy"])
            if area < ANN_AREA_FILTER_THRESHOLD:
              print(f"Ann (cat_id={cat_id}, og_obj_id={og_obj_id}, t={curr_time}) has unreasonably small area: {area}")
            elif curr_time > higest_z:
              print(f"Ann (cat_id={cat_id}, og_obj_id={og_obj_id}, t={curr_time}) exceeds video length, so gets ignored")
            else:
              curr_obj_id, curr_obj_id_dict = getCurrObjId(curr_time, cat_id, og_obj_id, curr_obj_id_dict)
              
              if curr_obj_id != None:
                cocoAnnotations.append({
                                        "id": idGenerator.generateAnnId(curr_time_int, curr_obj_id), 
                                        "image_id": idGenerator.generateImageId(curr_time_int), 
                                        "category_id": cat_id, 
                                        "segmentation": getSegmentation(ann["xy"]), 
                                        "area": area, 
                                        "bbox": getBBox(ann["xy"]), 
                                        "iscrowd": 0,
                                      })

  return cocoAnnotations


def createCocoImageDict(w, h, higest_z, video_filename, idGenerator):
  cocoImages = []

  for z in range(0, ceil(higest_z * 10)):
    image_num_in_filename = str(z)
    image_num_in_filename = image_num_in_filename.zfill(idGenerator.digits_for_image)

    image_filename = f"{video_filename}_" + image_num_in_filename + ".jpg"
    
    cocoImages.append({
                        "id": idGenerator.generateImageId(z), 
                        "width": w, 
                        "height": h, 
                        "file_name": image_filename, 
                        "license": 0, 
                        "flickr_url": "", 
                        "coco_url": "", 
                        "date_captured": date.today().strftime("%m/%d/%Y"),
    })

  return cocoImages


def createCocoInfoDict(video_filename):
  return {
          "year": date.today().year, 
          "version": "", 
          "description": video_filename, 
          "contributor": "", 
          "url": "", 
          "date_created": date.today().strftime("%m/%d/%Y"),
  }

# from the original conveter
def createCocoLisenses():
  return [{
            "id": 0,
            "name": "Unknown License",
            "url": ""
        }]

def createCocoCategories():
  return [{
            "supercategory": "object_label",
            "id": 1,
            "name": "shark"
          },
          {
            "supercategory": "object_label",
            "id": 2,
            "name": "human"
          }]

def getFilenameWithoutPath(file_path):
  path_without_extension = os.path.splitext(file_path)[0]

  return path_without_extension.split("/")[-1]

def convertToCocoFormat(via_json_path, video_dir, coco_json_dir, video_id):
  with open(via_json_path, 'r') as f:
    via_json = json.load(f)

  via_json_name = getFilenameWithoutPath(via_json_path)
  print(f"============ video id = {video_id}, via json name = {via_json_name} ============")
  print()

  # assume that there is only one filename
  video_filename = via_json["file"]["1"]["fname"]
  video_path = video_dir + video_filename
  
  vid_info = ffmpeg.probe(video_path)

  # https://stackoverflow.com/questions/7362130/getting-video-dimension-resolution-width-x-height-from-ffmpeg
  height = int(vid_info['streams'][0]['height'])
  width = int(vid_info['streams'][0]['width'])
  print(f"h = {height}, w = {width}")

  # https://stackoverflow.com/questions/3844430/how-to-get-the-duration-of-a-video-in-python
  vid_length = float(vid_info['format']['duration'])
  print(f"vid length (in sec): {vid_length}")
  print()

  coco_json_save_path = coco_json_dir + via_json_name + "_coco.json"

  idGen = CocoIdGenerator(file_id = video_id)

  coco_json = {
                  "info": createCocoInfoDict(via_json_name), 
                  "images": createCocoImageDict(width, height, vid_length, via_json_name, idGen), 
                  "annotations": createCocoAnnotationDict(via_json["metadata"], via_json["attribute"], vid_length, idGen), 
                  "categories": createCocoCategories(),
                  "licenses": createCocoLisenses(),
                }
  
  print()

  with open(coco_json_save_path, 'w') as f:
    json.dump(coco_json, f)

# %%
convertToCocoFormat('via_annotations/20210910_SharkInsideLineUp_GreatInteraction_2.json', "videos/", "coco_annotations/", 22)
# Out:
# ============ video id = 22, via json name = 20210910_SharkInsideLineUp_GreatInteraction_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 55.9559
#
# Ann (cat_id=1, og_obj_id=0, t=0) doesn't have right format for xy labels, only expect 4 points for bounding box
# Ann (cat_id=2, og_obj_id=None, t=0.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=4.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=5.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=6.3) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=9.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=11.1) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=13) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=20.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=22.3) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=26.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=30.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=33.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=34) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=38) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=42.8) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=47.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=47.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=48.8) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=49.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=49.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=50.4) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=50) has unreasonably small area: 0.0

# %%
def convertAllViaToCoco(via_json_path, video_dir, coco_json_dir):
    via_json_files = []

    for dirpath, _, filenames in os.walk(via_json_path):
        # sort ascending
        filenames_sorted = sorted(filenames)

        for f in filenames_sorted:
            if os.path.splitext(f)[1] == ".json":
                via_json_files.append(os.path.join(dirpath, f))
    
    via_json_with_errors = []

    for i in range(len(via_json_files)):
        via_json_file = via_json_files[i]

        try: 
            convertToCocoFormat(via_json_file, video_dir, coco_json_dir, video_id = i)
        except:
            trace_error = traceback.format_exc()
            
            print(trace_error)

            print("xxxxxxxxxxx WARNING! xxxxxxxxxxx")
            print(f"xxxxxxx video id = {i}, via json name = {via_json_file} xxxxxxx")
            print()
            
            via_json_with_errors.append((via_json_file, i, trace_error))

            pass

    
    print("------------ List of VIA Files that Have Errors When Converting ------------")
    print("     format: (json file path, video id that should be used)")
    for p in via_json_with_errors:
        fpath, video_id, trace_error = p
        print((fpath, video_id))
        print(trace_error)
        print()

# %%
convertAllViaToCoco("via_annotations/", "videos/", "coco_annotations/")
# Out:
# ============ video id = 0, via json name = 20200805_OneSharkSUPFollowsKids ============
#
# h = 2160, w = 3840
# vid length (in sec): 55.188466
#
# Ann (cat_id=1, og_obj_id=None, t=0.7) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=1.9) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=3.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=6.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=7.7) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=10) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=21.7) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=22.9) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=22.9) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=28.8) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=37) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=44.3) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.325) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=9.625) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=9.925) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=13.325) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=19.325) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=40.625) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=55.188) already got added, so got ignored
#
# ============ video id = 1, via json name = 20200805_OneSharkSUPSurfers ============
#
# h = 2160, w = 3840
# vid length (in sec): 16.182833
#
# Ann (cat_id=2, og_obj_id=12, t=6.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=8, t=3.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=6, t=3.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=12, t=7.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=9.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=2, t=11.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=4, t=0.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=0.3) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.3) has unreasonably small area: 0.0
#
# ============ video id = 2, via json name = 2020731_JWSSeaLIonSUP ============
#
# h = 2160, w = 3840
# vid length (in sec): 47.680966
#
# Ann (cat_id=2, og_obj_id=0, t=5.402) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.502) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=1.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=23.1) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=1, t=25.9) already got added, so got ignored
#
# ============ video id = 3, via json name = 20210121_SUPNexttoShark ============
#
# h = 2160, w = 3840
# vid length (in sec): 22.956266
#
# Ann (cat_id=1, og_obj_id=None, t=5.417) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=7.397) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=None, t=15.492) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=5.849) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.949) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.049) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.149) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.249) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.349) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.449) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.549) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.649) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.749) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.849) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.949) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=7.049) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=7.149) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=7.249) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=7.349) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=7.449) already got added, so got ignored
#
# ============ video id = 4, via json name = 20210121_SUPNexttoShark_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 22.956266
#
# Ann (cat_id=2, og_obj_id=None, t=0.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=1.14) has unreasonably small area: -33.356515519999995
# Ann (cat_id=2, og_obj_id=None, t=1.14) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=15, t=1.54) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=28, t=2.86142) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=4.16142) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=8.75807) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=21.62309) has unreasonably small area: 0.0
#
# ============ video id = 5, via json name = 20210121_SharkNearTwoSurfers ============
#
# h = 2160, w = 3840
# vid length (in sec): 7.440766
#
# Ann (cat_id=1, og_obj_id=None, t=2.202) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=3.602) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.802) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.002) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.882) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=1, t=6.882) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.882) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.582) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.582) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=1, t=6.582) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=6.582) has unreasonably small area: 0.0
#
# ============ video id = 6, via json name = 20210401_ThreeSharksVeryCloseSurfers ============
#
# h = 2160, w = 3840
# vid length (in sec): 23.189833
#
# Ann (cat_id=1, og_obj_id=None, t=0.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=1.04) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=1.94) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=2, t=5.14) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=None, t=18.34) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=18.64) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=2, t=23.19) exceeds video length, so gets ignored
# Ann (cat_id=1, og_obj_id=1, t=23.19) exceeds video length, so gets ignored
# Ann (cat_id=1, og_obj_id=0, t=23.19) exceeds video length, so gets ignored
# Ann (cat_id=2, og_obj_id=None, t=2.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=10.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=10.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=1, t=23.19) exceeds video length, so gets ignored
# Ann (cat_id=2, og_obj_id=0, t=23.19) exceeds video length, so gets ignored
#
# ============ video id = 7, via json name = 20210401_ThreeSharksVeryCloseSurfers_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 23.189833
#
# Ann (cat_id=2, og_obj_id=0, t=0) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.2) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=1, t=6) already got added, so got ignored
#
# ============ video id = 8, via json name = 20210401_ThreeSurfersTwoSharks ============
#
# h = 2160, w = 3840
# vid length (in sec): 20.186833
#
# Ann (cat_id=2, og_obj_id=None, t=6.123) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=1, t=16.203) has unreasonably small area: -21266.152672
# Ann (cat_id=1, og_obj_id=0, t=17.503) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=17.783) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=1, t=17.783) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.783) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=1, t=17.783) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=2, t=17.783) already got added, so got ignored
#
# ============ video id = 9, via json name = 20210403_SharkAndBodyboarders ============
#
# h = 2160, w = 3840
# vid length (in sec): 29.195822
#
# Ann (cat_id=1, og_obj_id=None, t=3.8) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=22.8) has unreasonably small area: 0.0
#
# ============ video id = 10, via json name = 20210403_SharkAndBodyboarders_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 29.195822
#
# cannot use any attribute to find label
# error at getLabelAndId
# Ann (cat_id=None, og_obj_id=None, t=0.136) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=29.196) exceeds video length, so gets ignored
# Ann (cat_id=2, og_obj_id=1, t=29.196) exceeds video length, so gets ignored
# Ann (cat_id=2, og_obj_id=None, t=29.196) exceeds video length, so gets ignored
# Ann (cat_id=2, og_obj_id=1, t=1.54) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=2.04) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=9.56) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=9.56) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=17.406) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=2.74) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=4.84) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=5.54) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=11.16) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=17.906) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=27.406) has unreasonably small area: 0.0
#
# ============ video id = 11, via json name = 20210615_SharkUnderSurfer ============
#
# h = 2160, w = 3840
# vid length (in sec): 38.311767
#
# Ann (cat_id=2, og_obj_id=0, t=0) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=8.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=9.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=9.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=9.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=9.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=11.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=14.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=14.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=14.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=14.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=14.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=14.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=14.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=15.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=16.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=17.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=19.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=22.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=23.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=24.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=25.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=26.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=28.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=29.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=30.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=31.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=32.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=33.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=34.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=36.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.4) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.8) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=37.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=38) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=38.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=38.2) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=38.3) already got added, so got ignored
#
# ============ video id = 12, via json name = 20210812_JamesElizabethBrianWithShark_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 71.204456
#
# Ann (cat_id=2, og_obj_id=0, t=2.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=4.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=4.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=4.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=6.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=12.3) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=18.6) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=20.1) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=21.5) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=27.9) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=35.5) already got added, so got ignored
#
# ============ video id = 13, via json name = 20210812_JamesWithShark ============
#
# h = 2160, w = 3840
# vid length (in sec): 43.44
#
# Ann (cat_id=2, og_obj_id=None, t=0.64) has unreasonably small area: 0.0
#
# ============ video id = 14, via json name = 20210812_JamesWithShark2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 17.216
#
# Ann (cat_id=2, og_obj_id=None, t=1.903) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=3.303) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=15.703) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=15.803) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=11.245) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=13.012) has unreasonably small area: 0.0
#
# ============ video id = 15, via json name = 20210812_JamesWithShark3 ============
#
# h = 2160, w = 3840
# vid length (in sec): 18.451756
#
#
# ============ video id = 16, via json name = 20210812_JamesWithShark_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 43.44
#
# Ann (cat_id=2, og_obj_id=0, t=30.074) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=43.474) exceeds video length, so gets ignored
# Ann (cat_id=1, og_obj_id=0, t=43.574) exceeds video length, so gets ignored
#
# ============ video id = 17, via json name = 20210812_SharkOutsideLineUP ============
#
# h = 2160, w = 3840
# vid length (in sec): 37.4374
#
# Ann (cat_id=2, og_obj_id=None, t=0.44) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=1.14) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=2.64) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=21.44) has unreasonably small area: 0.0
#
# ============ video id = 18, via json name = 20210812_SharkOutsideLineUP_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 37.4374
#
# Ann (cat_id=1, og_obj_id=None, t=25.5) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=20) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=22.9) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=27) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=9.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=11.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=14.9) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=17.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=3.1) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=16) has unreasonably small area: 4.8841
# Ann (cat_id=2, og_obj_id=None, t=25.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=29.7) has unreasonably small area: -835.758008
# Ann (cat_id=2, og_obj_id=None, t=29.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=29.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=29.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=29.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=29.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=31.8) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=2.9) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=8) has unreasonably small area: 4.88631
# Ann (cat_id=2, og_obj_id=None, t=10.5) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=22) has unreasonably small area: 4.888520999999999
# Ann (cat_id=2, og_obj_id=None, t=25.3) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=7) has unreasonably small area: 4.888520999999999
# Ann (cat_id=2, og_obj_id=None, t=17.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=18.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=22.8) has unreasonably small area: 0.0
#
# ============ video id = 19, via json name = 20210910_SUPInteraction ============
#
# h = 2160, w = 3840
# vid length (in sec): 27.961256
#
#
# ============ video id = 20, via json name = 20210910_SharkInsideLineUp_GreatInteraction ============
#
# h = 2160, w = 3840
# vid length (in sec): 55.9559
#
# Ann (cat_id=1, og_obj_id=None, t=15.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=11.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=42.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=13.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=14.04) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=18.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=24.44) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=24.44) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=46.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.14) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=3, t=18.24) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=37.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=45.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=5.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=24.34) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=25.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=4, t=35.34) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=5, t=25.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=5, t=37.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=5, t=47.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=5, t=49.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=9.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=11.44) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=13.54) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=13.54) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=13.54) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=6, t=19.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=21.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=23.04) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=23.54) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=23.54) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=25.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=25.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=25.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=6, t=25.64) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=6, t=50.04) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=7, t=13.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=7, t=37.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=8, t=23.44) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=8, t=27.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=8, t=27.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=8, t=29.34) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=8, t=37.64) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=8, t=42.04) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=8, t=49.84) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=8, t=53.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=9, t=29.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=9, t=37.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=9, t=51.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=9, t=51.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=9, t=55.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=9, t=55.74) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=10, t=19.54) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=10, t=24.04) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=10, t=25.84) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=10, t=29.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=10, t=29.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=10, t=30.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=10, t=35.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=10, t=45.74) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=10, t=49.84) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=11, t=9.84) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=11, t=13.54) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=11, t=17.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=11, t=25.74) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=11, t=35.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=11, t=43.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=11, t=45.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=11, t=45.94) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=11, t=55.74) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=12, t=9.54) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=12, t=19.64) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=12, t=21.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=12, t=25.94) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=12, t=27.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=12, t=46.026) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=12, t=51.926) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=12, t=53.926) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=13, t=17.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=13, t=25.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=13, t=38.34) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=14, t=19.84) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=14, t=37.74) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=14, t=41.94) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=14, t=48.04) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=15, t=11.74) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=15, t=15.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=15, t=21.74) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=15, t=24.64) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=15, t=31.44) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=15, t=31.84) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=15, t=55.74) has unreasonably small area: 0.0
#
# ============ video id = 21, via json name = 20210910_SharkInsideLineUp_GreatInteraction_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 55.9559
#
# Ann (cat_id=1, og_obj_id=0, t=0) doesn't have right format for xy labels, only expect 4 points for bounding box
# Ann (cat_id=2, og_obj_id=None, t=0.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=4.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=5.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=6.3) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=9.7) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=11.1) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=13) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=20.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=22.3) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=26.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=30.4) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=33.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=34) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=38) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=42.8) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=47.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=47.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=48.8) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=49.2) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=49.6) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=50.4) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=50) has unreasonably small area: 0.0
#
# ============ video id = 22, via json name = 20210910_SharkSpeedingPastSurfers ============
#
# h = 2160, w = 3840
# vid length (in sec): 19.953256
#
# Ann (cat_id=2, og_obj_id=None, t=5.942) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=0.142) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.242) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.342) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.442) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.542) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=0.542) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=0.642) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.742) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.842) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.942) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.042) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.142) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.242) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.342) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.442) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.542) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.642) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.742) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.842) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=1.942) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.042) already got added, so got ignored
# ...
# Ann (cat_id=2, og_obj_id=0, t=3.142) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.242) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.342) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.442) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.542) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.642) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.742) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.842) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=3.942) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.042) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.142) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.242) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.342) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.442) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.542) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.642) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.742) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.842) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=4.942) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.042) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.142) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.242) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.342) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.442) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.542) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.642) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.742) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.842) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=5.942) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.042) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.142) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.242) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.342) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.86) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.04) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=10.96) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=6.542) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=1, t=6.542) already got added, so got ignored
#
# ============ video id = 23, via json name = 20210910_SharkSpeedingPastSurfers_2 ============
#
# h = 2160, w = 3840
# vid length (in sec): 19.953256
#
# Ann (cat_id=1, og_obj_id=0, t=5.09999) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=None, t=7.19999) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=16.15599) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=17.05599) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=5.09999) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=1, t=5.09999) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=10.69998) has unreasonably small area: 0.0
#
# ============ video id = 24, via json name = 20210910_SharkSwimmerSurfer ============
#
# h = 2160, w = 3840
# vid length (in sec): 34.200833
#
# Ann (cat_id=2, og_obj_id=None, t=32.032) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=0.247) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=0.247) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.247) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.247) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.247) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.247) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.247) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.247) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=0.247) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=0.247) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=1, t=0.247) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.287) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.367) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.447) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.487) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.567) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.647) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.687) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.767) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.847) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.887) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=0.967) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.047) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.087) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.167) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.247) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.347) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.387) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.467) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.547) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.587) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.667) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.747) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.787) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.867) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.947) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=1.987) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.067) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.147) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.187) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.267) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.347) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.387) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.467) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.547) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.587) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.667) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.747) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.787) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.867) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.947) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=2.987) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.067) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.147) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.187) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.267) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.347) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.387) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.467) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.547) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.587) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.667) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.747) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.787) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.867) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=3.907) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=3.947) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.987) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.067) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.147) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.187) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.267) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.347) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.387) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.467) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.547) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.587) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.667) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.747) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.787) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.867) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.947) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.987) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.067) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.147) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=5.187) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=5.187) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.267) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.347) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.387) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.467) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.547) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.587) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.667) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.747) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.787) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.867) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=5.907) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=5.947) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=5.987) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.067) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.147) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.187) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.267) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.347) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.387) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.467) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.547) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.587) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.667) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.747) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=6.787) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.402) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=0.587) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=1.687) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=6.487) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=6.487) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=7.687) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=14.987) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=20.907) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=3.9) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=None, t=3.9) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=1, t=11.068) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=None, t=30.044) has unreasonably small area: 0
# Ann (cat_id=2, og_obj_id=None, t=19.287) has unreasonably small area: 0
# Ann (cat_id=2, og_obj_id=None, t=19.287) has unreasonably small area: 0
# Ann (cat_id=2, og_obj_id=1, t=21.507) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=22.107) has unreasonably small area: 0
# Ann (cat_id=2, og_obj_id=None, t=24.707) has unreasonably small area: 0
# Ann (cat_id=2, og_obj_id=None, t=25.907) has unreasonably small area: 0
# Ann (cat_id=2, og_obj_id=None, t=30.044) has unreasonably small area: 0
#
# ============ video id = 25, via json name = 20210910_SurferTowardsShark ============
#
# h = 2160, w = 3840
# vid length (in sec): 28.46
#
# Ann (cat_id=1, og_obj_id=0, t=4.991) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=2.7) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=5, t=26.09999) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=26.19999) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=3, t=26.19999) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=4, t=26.19999) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=7, t=26.19999) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=8, t=26.19999) already got added, so got ignored
#
# ============ video id = 26, via json name = DJI_0386 ============
#
# h = 2160, w = 3840
# vid length (in sec): 76.609867
#
# Ann (cat_id=2, og_obj_id=None, t=10.791) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=3.522) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=0.192) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=3.581) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=None, t=13.022) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=None, t=14.122) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=14.967) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=15.067) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=27.773) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=29.036) has unreasonably small area: 0.0
# Ann (cat_id=1, og_obj_id=0, t=29.036) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.092) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.192) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.292) already got added, so got ignored
# Ann (cat_id=1, og_obj_id=0, t=4.392) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=None, t=73.836) has unreasonably small area: 0.0
# Ann (cat_id=2, og_obj_id=0, t=74.336) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=74.436) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=74.536) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=74.636) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=74.736) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=74.836) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=74.936) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=75.036) already got added, so got ignored
# Ann (cat_id=2, og_obj_id=0, t=76.61) exceeds video length, so gets ignored
# Ann (cat_id=1, og_obj_id=0, t=76.61) exceeds video length, so gets ignored
#
# ------------ List of VIA Files that Have Errors When Converting ------------
#      format: (json file path, video id that should be used)

# %%
via_json_files = []
for dirpath, dirnames, filenames in os.walk('via_annotations/'):
    filenames_sorted = sorted(filenames)
    print(filenames_sorted)
    for f in filenames_sorted:
        if os.path.splitext(f)[1] == ".json":
            via_json_files.append(os.path.join(dirpath, f))
print(via_json_files)
# Out:
# ['.DS_Store', '20200805_OneSharkSUPFollowsKids.json', '20200805_OneSharkSUPSurfers.json', '2020731_JWSSeaLIonSUP.json', '20210121_SUPNexttoShark.json', '20210121_SUPNexttoShark_2.json', '20210121_SharkNearTwoSurfers.json', '20210401_ThreeSharksVeryCloseSurfers.json', '20210401_ThreeSharksVeryCloseSurfers_2.json', '20210401_ThreeSurfersTwoSharks.json', '20210403_SharkAndBodyboarders.json', '20210403_SharkAndBodyboarders_2.json', '20210615_SharkUnderSurfer.json', '20210812_JamesElizabethBrianWithShark.json', '20210812_JamesElizabethBrianWithShark_2.json', '20210812_JamesWithShark.json', '20210812_JamesWithShark2.json', '20210812_JamesWithShark3.json', '20210812_JamesWithShark_2.json', '20210812_SharkOutsideLineUP.json', '20210812_SharkOutsideLineUP_2.json', '20210910_SUPInteraction.json', '20210910_SharkInsideLineUp_GreatInteraction.json', '20210910_SharkInsideLineUp_GreatInteraction_2.json', '20210910_SharkSpeedingPastSurfers.json', '20210910_SharkSpeedingPastSurfers_2.json', '20210910_SharkSwimmerSurfer.json', '20210910_SurferTowardsShark.json', 'DJI_0386.json']
# ['via_annotations/20200805_OneSharkSUPFollowsKids.json', 'via_annotations/20200805_OneSharkSUPSurfers.json', 'via_annotations/2020731_JWSSeaLIonSUP.json', 'via_annotations/20210121_SUPNexttoShark.json', 'via_annotations/20210121_SUPNexttoShark_2.json', 'via_annotations/20210121_SharkNearTwoSurfers.json', 'via_annotations/20210401_ThreeSharksVeryCloseSurfers.json', 'via_annotations/20210401_ThreeSharksVeryCloseSurfers_2.json', 'via_annotations/20210401_ThreeSurfersTwoSharks.json', 'via_annotations/20210403_SharkAndBodyboarders.json', 'via_annotations/20210403_SharkAndBodyboarders_2.json', 'via_annotations/20210615_SharkUnderSurfer.json', 'via_annotations/20210812_JamesElizabethBrianWithShark.json', 'via_annotations/20210812_JamesElizabethBrianWithShark_2.json', 'via_annotations/20210812_JamesWithShark.json', 'via_annotations/20210812_JamesWithShark2.json', 'via_annotations/20210812_JamesWithShark3.json', 'via_annotations/20210812_JamesWithShark_2.json', 'via_annotations/20210812_SharkOutsideLineUP.json', 'via_annotations/20210812_SharkOutsideLineUP_2.json', 'via_annotations/20210910_SUPInteraction.json', 'via_annotations/20210910_SharkInsideLineUp_GreatInteraction.json', 'via_annotations/20210910_SharkInsideLineUp_GreatInteraction_2.json', 'via_annotations/20210910_SharkSpeedingPastSurfers.json', 'via_annotations/20210910_SharkSpeedingPastSurfers_2.json', 'via_annotations/20210910_SharkSwimmerSurfer.json', 'via_annotations/20210910_SurferTowardsShark.json', 'via_annotations/DJI_0386.json']
